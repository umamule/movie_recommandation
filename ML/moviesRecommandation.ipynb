# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\umule\appdata\roaming\python\python312\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\umule\appdata\roaming\python\python312\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip list --outdated
# Out:
# Package                           Version            Latest              Type
# --------------------------------- ------------------ ------------------- -----
# aiobotocore                       2.12.3             2.15.1              wheel
# aiohttp                           3.9.5              3.10.5              wheel
# aioitertools                      0.7.1              0.12.0              wheel
# aiosignal                         1.2.0              1.3.1               wheel
# alabaster                         0.7.16             1.0.0               wheel
# anaconda-cloud-auth               0.5.1              0.6.0               wheel
# annotated-types                   0.6.0              0.7.0               wheel
# anyio                             4.2.0              4.5.0               wheel
# archspec                          0.2.3              0.2.4               wheel
# argon2-cffi                       21.3.0             23.1.0              wheel
# arrow                             1.2.3              1.3.0               wheel
# astroid                           2.14.2             3.3.3               wheel
# astropy                           6.1.0              6.1.3               wheel
# astropy-iers-data                 0.2024.6.3.0.31.14 0.2024.9.16.0.32.21 wheel
# atomicwrites                      1.4.0              1.4.1               sdist
# Automat                           20.2.0             24.8.1              wheel
# autopep8                          2.0.4              2.3.1               wheel
# Babel                             2.11.0             2.16.0              wheel
# bcrypt                            3.2.0              4.2.0               wheel
# black                             24.4.2             24.8.0              wheel
# bleach                            4.1.0              6.1.0               wheel
# bokeh                             3.4.1              3.5.2               wheel
# boltons                           23.0.0             24.0.0              wheel
# botocore                          1.34.69            1.35.24             wheel
# Bottleneck                        1.3.7              1.4.0               wheel
# Brotli                            1.0.9              1.1.0               wheel
# cffi                              1.16.0             1.17.1              wheel
# chardet                           4.0.0              5.2.0               wheel
# cloudpickle                       2.2.1              3.0.0               wheel
# conda-pack                        0.7.1              0.8.0               wheel
# contourpy                         1.2.0              1.3.0               wheel
# cryptography                      42.0.5             43.0.1              wheel
# cycler                            0.11.0             0.12.1              wheel
# cytoolz                           0.12.2             0.12.3              wheel
# dask                              2024.5.0           2024.9.0            wheel
# dask-expr                         1.1.0              1.1.14              wheel
# datashader                        0.16.2             0.16.3              wheel
# diff-match-patch                  20200713           20230430            wheel
# distributed                       2024.5.0           2024.9.0            wheel
# docstring-to-markdown             0.11               0.15                wheel
# docutils                          0.18.1             0.21.2              wheel
# fastjsonschema                    2.16.2             2.20.0              wheel
# filelock                          3.13.1             3.16.1              wheel
# flake8                            7.0.0              7.1.1               wheel
# fonttools                         4.51.0             4.53.1              wheel
# frozendict                        2.4.2              2.4.4               wheel
# frozenlist                        1.4.0              1.4.1               wheel
# fsspec                            2024.3.1           2024.9.0            wheel
# gensim                            4.3.2              4.3.3               wheel
# greenlet                          3.0.1              3.1.1               wheel
# holoviews                         1.19.0             1.19.1              wheel
# httpcore                          1.0.2              1.0.5               wheel
# httpx                             0.27.0             0.27.2              wheel
# imagecodecs                       2023.1.23          2024.6.1            wheel
# imageio                           2.33.1             2.35.1              wheel
# importlib-metadata                7.0.1              8.5.0               wheel
# incremental                       22.10.0            24.7.2              wheel
# iniconfig                         1.1.1              2.0.0               wheel
# intake                            0.7.0              2.0.7               wheel
# ipywidgets                        7.8.1              8.1.5               wheel
# itemadapter                       0.3.0              0.9.0               wheel
# itemloaders                       1.1.0              1.3.1               wheel
# jaraco.classes                    3.2.1              3.4.0               wheel
# jellyfish                         1.0.1              1.1.0               wheel
# json5                             0.9.6              0.9.25              wheel
# jsonpointer                       2.1                3.0.0               wheel
# jupyter                           1.0.0              1.1.1               wheel
# jupyter_client                    8.6.2              8.6.3               wheel
# jupyter-lsp                       2.2.0              2.2.5               wheel
# jupyter_server                    2.14.1             2.14.2              wheel
# jupyter_server_terminals          0.4.4              0.5.3               wheel
# jupyterlab                        4.0.11             4.2.5               wheel
# jupyterlab-pygments               0.1.2              0.3.0               wheel
# jupyterlab_server                 2.25.1             2.27.3              wheel
# jupyterlab-widgets                1.0.0              3.0.13              wheel
# keyring                           24.3.1             25.4.1              wheel
# kiwisolver                        1.4.4              1.4.7               wheel
# lckr_jupyterlab_variableinspector 3.1.0              3.2.4               wheel
# libarchive-c                      2.9                5.1                 wheel
# linkify-it-py                     2.0.0              2.0.3               wheel
# llvmlite                          0.42.0             0.43.0              wheel
# lmdb                              1.4.1              1.5.1               wheel
# lxml                              5.2.1              5.3.0               wheel
# lz4                               4.3.2              4.3.3               wheel
# Markdown                          3.4.1              3.7                 wheel
# matplotlib                        3.8.4              3.9.2               wheel
# mdit-py-plugins                   0.3.0              0.4.2               wheel
# mistune                           2.0.4              3.0.2               wheel
# more-itertools                    10.1.0             10.5.0              wheel
# msgpack                           1.0.3              1.1.0               wheel
# multidict                         6.0.4              6.1.0               wheel
# multipledispatch                  0.6.0              1.0.0               wheel
# mypy                              1.10.0             1.11.2              wheel
# narwhals                          1.8.1              1.8.2               wheel
# nbclient                          0.8.0              0.10.0              wheel
# nbconvert                         7.10.0             7.16.4              wheel
# nbformat                          5.9.2              5.10.4              wheel
# networkx                          3.2.1              3.3                 wheel
# notebook                          7.0.8              7.2.2               wheel
# notebook_shim                     0.2.3              0.2.4               wheel
# numba                             0.59.1             0.60.0              wheel
# numexpr                           2.8.7              2.10.1              wheel
# numpydoc                          1.7.0              1.8.0               wheel
# openpyxl                          3.1.2              3.1.5               wheel
# overrides                         7.4.0              7.7.0               wheel
# pandas                            2.2.2              2.2.3               wheel
# pandocfilters                     1.5.0              1.5.1               wheel
# panel                             1.4.4              1.5.0               wheel
# param                             2.1.0              2.1.1               wheel
# paramiko                          2.8.1              3.5.0               wheel
# parsel                            1.8.1              1.9.1               wheel
# partd                             1.4.1              1.4.2               wheel
# pathspec                          0.10.3             0.12.1              wheel
# pexpect                           4.8.0              4.9.0               wheel
# pip                               24.0               24.2                wheel
# pkginfo                           1.10.0             1.11.1              wheel
# platformdirs                      4.3.3              4.3.6               wheel
# plotly                            5.22.0             5.24.1              wheel
# pluggy                            1.0.0              1.5.0               wheel
# prometheus-client                 0.14.1             0.21.0              wheel
# Protego                           0.1.16             0.3.1               wheel
# protobuf                          5.28.1             5.28.2              wheel
# pyasn1                            0.4.8              0.6.1               wheel
# pyasn1-modules                    0.2.8              0.4.1               wheel
# pycodestyle                       2.11.1             2.12.1              wheel
# pycparser                         2.21               2.22                wheel
# pycurl                            7.45.2             7.45.3              wheel
# pydantic                          2.5.3              2.9.2               wheel
# pydantic_core                     2.14.6             2.24.0              wheel
# PyDispatcher                      2.0.5              2.0.7               wheel
# PyJWT                             2.8.0              2.9.0               wheel
# pylint                            2.16.2             3.3.0               wheel
# pyodbc                            5.0.1              5.1.0               wheel
# pyOpenSSL                         24.0.0             24.2.1              wheel
# pyparsing                         3.0.9              3.1.4               wheel
# PyQt5                             5.15.10            5.15.11             wheel
# PyQt5-sip                         12.13.0            12.15.0             wheel
# PyQtWebEngine                     5.15.6             5.15.7              wheel
# pytest                            7.4.4              8.3.3               wheel
# python-dotenv                     0.21.0             1.0.1               wheel
# python-lsp-server                 1.10.0             1.12.0              wheel
# python-slugify                    5.0.2              8.0.4               wheel
# python-snappy                     0.6.1              0.7.3               wheel
# pytoolconfig                      1.2.6              1.3.1               wheel
# pyviz_comms                       3.0.2              3.0.3               wheel
# pywavelets                        1.5.0              1.7.0               wheel
# pywin32-ctypes                    0.2.2              0.2.3               wheel
# pywinpty                          2.0.10             2.0.13              wheel
# PyYAML                            6.0.1              6.0.2               wheel
# qstylizer                         0.2.2              0.2.3               wheel
# QtAwesome                         1.2.2              1.3.1               wheel
# qtconsole                         5.5.1              5.6.0               wheel
# queuelib                          1.6.2              1.7.0               wheel
# requests-file                     1.5.1              2.1.0               wheel
# rope                              1.12.0             1.13.0              wheel
# Rtree                             1.0.1              1.3.0               wheel
# ruamel.yaml                       0.17.21            0.18.6              wheel
# s3fs                              2024.3.1           2024.9.0            wheel
# scikit-image                      0.23.2             0.24.0              wheel
# Scrapy                            2.11.1             2.11.2              wheel
# Send2Trash                        1.8.2              1.8.3               wheel
# service-identity                  18.1.0             24.1.0              wheel
# setuptools                        69.5.1             75.1.0              wheel
# sip                               6.7.12             6.8.6               wheel
# smart-open                        5.2.1              7.0.4               wheel
# sniffio                           1.3.0              1.3.1               wheel
# soupsieve                         2.5                2.6                 wheel
# Sphinx                            7.3.7              8.0.2               wheel
# sphinxcontrib-applehelp           1.0.2              2.0.0               wheel
# sphinxcontrib-devhelp             1.0.2              2.0.0               wheel
# sphinxcontrib-htmlhelp            2.0.0              2.1.0               wheel
# sphinxcontrib-qthelp              1.0.3              2.0.0               wheel
# sphinxcontrib-serializinghtml     1.1.10             2.0.0               wheel
# spyder                            5.5.1              6.0.0               wheel
# spyder-kernels                    2.5.0              3.0.0               wheel
# SQLAlchemy                        2.0.30             2.0.35              wheel
# statsmodels                       0.14.2             0.14.3              wheel
# sympy                             1.12               1.13.3              wheel
# tables                            3.9.2              3.10.1              wheel
# tblib                             1.7.0              3.0.0               wheel
# tenacity                          8.5.0              9.0.0               wheel
# terminado                         0.17.1             0.18.1              wheel
# textdistance                      4.2.1              4.6.3               wheel
# tifffile                          2023.4.12          2024.9.20           wheel
# tinycss2                          1.2.1              1.3.0               wheel
# tldextract                        3.2.0              5.1.2               wheel
# tomlkit                           0.11.1             0.13.2              wheel
# toolz                             0.12.0             0.12.1              wheel
# truststore                        0.8.0              0.9.2               wheel
# Twisted                           23.10.0            24.7.0              wheel
# twisted-iocpsupport               1.0.2              1.0.4               wheel
# uc-micro-py                       1.0.1              1.0.3               wheel
# Unidecode                         1.2.0              1.3.8               wheel
# w3lib                             2.1.2              2.2.1               wheel
# watchdog                          4.0.2              5.0.2               wheel
# Werkzeug                          3.0.3              3.0.4               wheel
# whatthepatch                      1.0.2              1.0.6               wheel
# wheel                             0.43.0             0.44.0              wheel
# widgetsnbextension                3.6.6              4.0.13              wheel
# wrapt                             1.14.1             1.16.0              wheel
# xarray                            2023.6.0           2024.9.0            wheel
# xlwings                           0.31.4             0.32.2              wheel
# xyzservices                       2022.9.0           2024.9.0            wheel
# yarl                              1.9.3              1.11.1              wheel
# zipp                              3.17.0             3.20.2              wheel
# zope.interface                    5.4.0              7.0.3               wheel
# zstandard                         0.22.0             0.23.0              wheel
# Note: you may need to restart the kernel to use updated packages.

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
pip install --upgrade scipy scikit-learn
# Out:
# Requirement already satisfied: scipy in c:\users\umule\anaconda3\lib\site-packages (1.14.1)
# Requirement already satisfied: scikit-learn in c:\users\umule\anaconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\umule\appdata\roaming\python\python312\site-packages (from scipy) (2.1.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\umule\appdata\roaming\python\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\umule\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
movies.shape
# Out:
# (4803, 20)

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies = movies.merge(credits,on='title')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def convert(obj):
    L=[]
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies.dropna(inplace=True)

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
import ast
ast.literal_eval('[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]')
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 878, 'name': 'Science Fiction'}]

# %%
def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
        counter+=1
    return L

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.sample(5)
# Out:
#       movie_id                title  \
# 4417     37694                Proud
# 1940      8338            Blindness
# 1872      9655        She's the Man
# 4686     54702          Malevolence
# 4506    181940  Carousel of Revenge
#
#                                                overview  \
# 4417  The true story of the only African-American cr...
# 1940  When a sudden plague of blindness devastates a...
# 1872  Viola Johnson is in a real jam. Complications ...
# 4686  It's ten years after the kidnapping of Martin ...
# 4506  When strangers Frank Delano and his Uncle Bobb...
#
#                                            genres  \
# 4417                                      [Drama]
# 1940  [Drama, Mystery, Science Fiction, Thriller]
# 1872             [Comedy, Drama, Family, Romance]
# 4686                    [Crime, Horror, Thriller]
# 4506                          [Thriller, Mystery]
#
#                                                keywords  \
# 4417                                   [woman director]
# 1940  [fight, blindness and impaired vision, asylum,...
# 1872  [roommate, twin sister, sport, boarding school...
# 4686  [hostage, psychopath, abandoned house, serial ...
# 4506                                                 []
#
#                                                  cast                  crew
# 4417  [Vernel Bagneris, Marcus Chait, Michael Ciesla]      [Mary Pat Kelly]
# 1940      [Julianne Moore, Mark Ruffalo, Alice Braga]  [Fernando Meirelles]
# 1872     [Amanda Bynes, Channing Tatum, Laura Ramsey]        [Andy Fickman]
# 4686   [Samantha Dark, Heather Magee, Richard Glover]         [Stevan Mena]
# 4506     [Erik Allen, Randy Baranczyk, Chris Carlson]       [Gene Teigland]

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
new = movies.drop(columns=['overview','genres','keywords','cast','crew'])
#new.head()

# %%
new['tags'] = new['tags'].apply(lambda x: " ".join(x))
new.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\umule\appdata\roaming\python\python312\site-packages (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy.core.multiarray

# %%
from sklearn.feature_extraction.text import CountVectorizer
cvs= CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cvs.fit_transform(new['tags']).toarray()

# %%
vector.shape
# Out:
# (4806, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.09107651, 0.06071767, ..., 0.02519763, 0.02817181,
#         0.        ],
#        [0.09107651, 1.        , 0.06451613, ..., 0.02677398, 0.        ,
#         0.        ],
#        [0.06071767, 0.06451613, 1.        , ..., 0.02677398, 0.        ,
#         0.        ],
#        ...,
#        [0.02519763, 0.02677398, 0.02677398, ..., 1.        , 0.0745356 ,
#         0.04774099],
#        [0.02817181, 0.        , 0.        , ..., 0.0745356 , 1.        ,
#         0.05337605],
#        [0.        , 0.        , 0.        , ..., 0.04774099, 0.05337605,
#         1.        ]])

# %%
new[new['title'] == 'The Lego Movie'].index[0]
# Out:
# np.int64(744)

# %%
def recommend(movie):
    index = new[new['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:6]:
        print(new.iloc[i[0]].title)

# %%
recommend('Gandhi')
# Out:
# Gandhi, My Father
# The Wind That Shakes the Barley
# A Passage to India
# Guiana 1838
# Bloody Sunday

# %%
import pickle

# %%
pickle.dump(new,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
